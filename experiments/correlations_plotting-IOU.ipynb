# %%
import torch
import os
from collections import defaultdict
from scipy.spatial import distance
from scipy.stats import spearmanr
import numpy as np
import json
from collections import defaultdict
import pandas as pd

with open('data/didec/didec_image_specificity_selfbleu.json', 'r') as f:
    selfbleu = json.load(f)

with open('startingpoint_var.json', 'r') as f:
    spvar = json.load(f)

with open('gaze_variation_IOU.json', 'r') as f:
    gazeIOU = json.load(f)

with open('onset_means.json', 'r') as f:
    onsets = json.load(f)

specs = []
specs_revbleu = []
spvars = []
gazevars = []
means = []

for im in selfbleu:
    specs.append(selfbleu[im])
    specs_revbleu.append(1 - selfbleu[im])
    spvars.append(spvar[im])
    gazevars.append(gazeIOU[im])
    means.append(onsets[im])

print(np.mean(spvars), np.min(spvars), np.max(spvars))

corr, pvalue = spearmanr(spvars, specs)
print('correlation sp var vs. img spec')
print(round(corr, 3), round(pvalue, 3))

corr, pvalue = spearmanr(spvars, gazevars)
print('correlation sp var vs. gaze var')
print(round(corr, 3), round(pvalue, 3))

corr, pvalue = spearmanr(gazevars, specs)
print('correlation gaze var vs. img spec')
print(round(corr, 3), round(pvalue, 3))

# onset
corr, pvalue = spearmanr(spvars, means)
print('correlation sp var vs. mean onset')
print(round(corr, 3), round(pvalue, 3))

corr, pvalue = spearmanr(means, specs)
print('correlation mean onset vs. img spec')
print(round(corr, 3), round(pvalue, 3))

corr, pvalue = spearmanr(gazevars, means)
print('correlation gaze var vs. mean onset')
print(round(corr, 3), round(pvalue, 3))
# Out:
# 6.449511400651466 1 13
# correlation sp var vs. img spec
# -0.516 0.0
# correlation sp var vs. gaze var
# 0.35 0.0
# correlation gaze var vs. img spec
# -0.485 0.0
# correlation sp var vs. mean onset
# 0.275 0.0
# correlation mean onset vs. img spec
# -0.391 0.0
# correlation gaze var vs. mean onset
# 0.455 0.0

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 4))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# Out:
# /tmp/ipykernel_26439/833975462.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# <style type="text/css">
# #T_32cfb_row0_col0, #T_32cfb_row1_col1, #T_32cfb_row2_col2, #T_32cfb_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_32cfb_row0_col1, #T_32cfb_row1_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_32cfb_row0_col2, #T_32cfb_row2_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_32cfb_row0_col3, #T_32cfb_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_32cfb_row1_col2, #T_32cfb_row2_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_32cfb_row1_col3, #T_32cfb_row3_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_32cfb_row2_col3, #T_32cfb_row3_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# </style>
# <table id="T_32cfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32cfb_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_32cfb_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_32cfb_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_32cfb_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32cfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32cfb_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_32cfb_row0_col1" class="data row0 col1" >-0.251</td>
#       <td id="T_32cfb_row0_col2" class="data row0 col2" >0.197</td>
#       <td id="T_32cfb_row0_col3" class="data row0 col3" >-0.392</td>
#     </tr>
#     <tr>
#       <th id="T_32cfb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32cfb_row1_col0" class="data row1 col0" >-0.251</td>
#       <td id="T_32cfb_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_32cfb_row1_col2" class="data row1 col2" >-0.115</td>
#       <td id="T_32cfb_row1_col3" class="data row1 col3" >-0.262</td>
#     </tr>
#     <tr>
#       <th id="T_32cfb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32cfb_row2_col0" class="data row2 col0" >0.197</td>
#       <td id="T_32cfb_row2_col1" class="data row2 col1" >-0.115</td>
#       <td id="T_32cfb_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_32cfb_row2_col3" class="data row2 col3" >0.194</td>
#     </tr>
#     <tr>
#       <th id="T_32cfb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32cfb_row3_col0" class="data row3 col0" >-0.392</td>
#       <td id="T_32cfb_row3_col1" class="data row3 col1" >-0.262</td>
#       <td id="T_32cfb_row3_col2" class="data row3 col2" >0.194</td>
#       <td id="T_32cfb_row3_col3" class="data row3 col3" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
didec = pd.DataFrame([means, spvars, specs_revbleu, gazevars]).T

# %%
didec
# Out:
#             0    1         2          3
# 0    2.485543  6.0  0.512203  14.740623
# 1    3.620091  4.0  0.382698  28.421684
# 2    2.770923  7.0  0.561931  26.239805
# 3    4.384597  4.0  0.505561  25.927455
# 4    3.956366  4.0  0.327507  27.003245
# ..        ...  ...       ...        ...
# 302  4.207784  7.0  0.511987  25.450254
# 303  3.168497  6.0  0.580847  26.720168
# 304  2.133036  6.0  0.435684  21.464699
# 305  3.735631  7.0  0.606961  20.437832
# 306  4.241220  5.0  0.381041  23.417972
#
# [307 rows x 4 columns]

# %%
corr = didec.corr(method='spearman')
corr
# Out:
#           0         1         2         3
# 0  1.000000  0.275302  0.391332  0.454510
# 1  0.275302  1.000000  0.515977  0.349778
# 2  0.391332  0.515977  1.000000  0.484991
# 3  0.454510  0.349778  0.484991  1.000000

# %%
corr.columns = ['Onset', 'SPvar', 'ImSpec', 'GazeVar']
corr.index = ['Onset', 'SPvar', 'ImSpec', 'GazeVar']
corr
# Out:
#             Onset     SPvar    ImSpec   GazeVar
# Onset    1.000000  0.275302  0.391332  0.454510
# SPvar    0.275302  1.000000  0.515977  0.349778
# ImSpec   0.391332  0.515977  1.000000  0.484991
# GazeVar  0.454510  0.349778  0.484991  1.000000

# %%
didec.columns = ['Onset', 'Starting', 'Description', 'Gaze']
didec
# Out:
#         Onset  Starting  Description       Gaze
# 0    2.485543       6.0     0.512203  14.740623
# 1    3.620091       4.0     0.382698  28.421684
# 2    2.770923       7.0     0.561931  26.239805
# 3    4.384597       4.0     0.505561  25.927455
# 4    3.956366       4.0     0.327507  27.003245
# ..        ...       ...          ...        ...
# 302  4.207784       7.0     0.511987  25.450254
# 303  3.168497       6.0     0.580847  26.720168
# 304  2.133036       6.0     0.435684  21.464699
# 305  3.735631       7.0     0.606961  20.437832
# 306  4.241220       5.0     0.381041  23.417972
#
# [307 rows x 4 columns]

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None).format(precision=3)
# Out:
# <style type="text/css">
# #T_bb416_row0_col0, #T_bb416_row1_col1, #T_bb416_row2_col2, #T_bb416_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bb416_row0_col1, #T_bb416_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bb416_row0_col2, #T_bb416_row2_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_bb416_row0_col3, #T_bb416_row3_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_bb416_row1_col2, #T_bb416_row2_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_bb416_row1_col3, #T_bb416_row3_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_bb416_row2_col3, #T_bb416_row3_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# </style>
# <table id="T_bb416">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb416_level0_col0" class="col_heading level0 col0" >Onset</th>
#       <th id="T_bb416_level0_col1" class="col_heading level0 col1" >SPvar</th>
#       <th id="T_bb416_level0_col2" class="col_heading level0 col2" >ImSpec</th>
#       <th id="T_bb416_level0_col3" class="col_heading level0 col3" >GazeVar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb416_level0_row0" class="row_heading level0 row0" >Onset</th>
#       <td id="T_bb416_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_bb416_row0_col1" class="data row0 col1" >0.275</td>
#       <td id="T_bb416_row0_col2" class="data row0 col2" >0.391</td>
#       <td id="T_bb416_row0_col3" class="data row0 col3" >0.455</td>
#     </tr>
#     <tr>
#       <th id="T_bb416_level0_row1" class="row_heading level0 row1" >SPvar</th>
#       <td id="T_bb416_row1_col0" class="data row1 col0" >0.275</td>
#       <td id="T_bb416_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_bb416_row1_col2" class="data row1 col2" >0.516</td>
#       <td id="T_bb416_row1_col3" class="data row1 col3" >0.350</td>
#     </tr>
#     <tr>
#       <th id="T_bb416_level0_row2" class="row_heading level0 row2" >ImSpec</th>
#       <td id="T_bb416_row2_col0" class="data row2 col0" >0.391</td>
#       <td id="T_bb416_row2_col1" class="data row2 col1" >0.516</td>
#       <td id="T_bb416_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_bb416_row2_col3" class="data row2 col3" >0.485</td>
#     </tr>
#     <tr>
#       <th id="T_bb416_level0_row3" class="row_heading level0 row3" >GazeVar</th>
#       <td id="T_bb416_row3_col0" class="data row3 col0" >0.455</td>
#       <td id="T_bb416_row3_col1" class="data row3 col1" >0.350</td>
#       <td id="T_bb416_row3_col2" class="data row3 col2" >0.485</td>
#       <td id="T_bb416_row3_col3" class="data row3 col3" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.heatmap(didec.corr(method='spearman'), annot=True, fmt='.3f', 
            cmap=plt.get_cmap('coolwarm'), cbar=True, ax=ax, 
            annot_kws={"fontsize":12}, square=True, linewidths=1, cbar_kws={'label': 'Spearman\'s ρ'})
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
plt.savefig('correlations_iou.png', dpi=300, bbox_inches='tight', pad_inches=0.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.heatmap(didec.corr(method='spearman'), annot=True, fmt='.3f', 
            cmap=plt.get_cmap('Blues'), cbar=True, ax=ax, 
            annot_kws={"fontsize":12}, square=True, linewidths=1, cbar_kws={'label': 'Spearman\'s ρ'})
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
plt.savefig('correlations_iou.png', dpi=300, bbox_inches='tight', pad_inches=0.0)

# %%
didec.corr(method='spearman')
# Out:
#                 Onset  Starting  Description      Gaze
# Onset        1.000000  0.275302     0.391332  0.454510
# Starting     0.275302  1.000000     0.515977  0.349778
# Description  0.391332  0.515977     1.000000  0.484991
# Gaze         0.454510  0.349778     0.484991  1.000000

# %%
dc = didec.corr(method='spearman')

# %%
trimask = np.triu(np.ones_like(dc, dtype=bool))
trimask
# Out:
# array([[ True,  True,  True,  True],
#        [False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False,  True]])

# %%
trimask[np.diag_indices_from(trimask)] = False

# %%
trimask
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False,  True],
#        [False, False, False, False]])

# %%
fig, ax = plt.subplots()
sns.heatmap(didec.corr(method='spearman'), annot=True, fmt='.3f', 
            cmap=plt.get_cmap('Reds'), cbar=True, ax=ax, 
            annot_kws={"fontsize":12}, square=True, linewidths=1, cbar_kws={'label': 'Spearman\'s ρ'},
           mask = trimask)
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
plt.savefig('correlations_iou_red.png', dpi=300, bbox_inches='tight', pad_inches=0.0)
